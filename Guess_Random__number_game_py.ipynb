# %% [markdown]
# <a href="https://colab.research.google.com/github/Lodi17/Guess-the-Random-numbers-between-1-100-/blob/main/Guess_Random__number_game_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Simple Number Guessing Game
def number_game():
    # Computer picks a random number between 1 and 100
    secret_number = random.randint(1, 100)
    attempts = 0
    guess = None

    print("=" * 40)
    print("Welcome to Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100")
    print("=" * 40)

    # Loop until user guesses correctly
    while guess != secret_number:
        try:
            guess = int(input("\nGuess the number: "))
            attempts += 1

            if guess < secret_number:
                print("📈 Too low! Try higher.")
            elif guess > secret_number:
                print("📉 Too high! Try lower.")
            else:
                print(f"\n🎉 Correct! You found it in {attempts} attempts!")

        except ValueError:
            print("❌ Please enter a valid number!")

    # Ask to play again
    play_again = input("\nWant to play again? (yes/no): ").lower()
    if play_again == "yes":
        number_game()
    else:
        print("Thanks for playing! Goodbye!")

# Run the game
if __name__ == "__main__":
    number_game()
# Out:
# ...
# Welcome to Number Guessing Game!
# I'm thinking of a number between 1 and 100
# ...
#
# Guess the number: 5
# 📈 Too low! Try higher.
#
# Guess the number: 67
# 📉 Too high! Try lower.
#
# Guess the number: 55
# 📉 Too high! Try lower.
#
# Guess the number: 50
# 📉 Too high! Try lower.
#
# Guess the number: 44
# 📈 Too low! Try higher.
#
# Guess the number: 47
# 📈 Too low! Try higher.
#
# Guess the number: 49
# 📉 Too high! Try lower.
#
# Guess the number: 48
#
# 🎉 Correct! You found it in 8 attempts!
